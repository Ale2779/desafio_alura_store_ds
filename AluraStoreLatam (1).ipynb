# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda.tail()
# Out:
#            Producto Categoría del Producto     Precio  Costo de envío  \
# 2354      Iphone 15           Electrónicos  1284400.0         66600.0
# 2355      Impresora           Electrónicos   282800.0         15300.0
# 2356  Juego de mesa               Juguetes   122900.0          7200.0
# 2357       Cama box                Muebles   691300.0         35000.0
# 2358     Smartwatch           Electrónicos   195000.0          8600.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 2354      15/11/2021  Izabela de León        Medellín             1
# 2355      18/03/2023    Lucas Olivera          Bogotá             5
# 2356      06/07/2021    Lucas Olivera            Cali             5
# 2357      02/05/2022      Pedro Gomez           Pasto             1
# 2358      18/06/2022    Felipe Santos            Cali             4
#
#           Método de pago  Cantidad de cuotas      lat       lon
# 2354               Nequi                   1  6.25184 -75.56359
# ...

# %%
pd.read_csv(url, sep=",")
# Out:
#                Producto Categoría del Producto     Precio  Costo de envío  \
# 0     Asistente virtual           Electrónicos   164300.0          6900.0
# 1       Mesa de comedor                Muebles   192300.0          8400.0
# 2         Juego de mesa               Juguetes   209600.0         15900.0
# 3            Microondas      Electrodomésticos   757500.0         41000.0
# 4      Silla de oficina                Muebles   335200.0         20200.0
# ...                 ...                    ...        ...             ...
# 2354          Iphone 15           Electrónicos  1284400.0         66600.0
# 2355          Impresora           Electrónicos   282800.0         15300.0
# 2356      Juego de mesa               Juguetes   122900.0          7200.0
# 2357           Cama box                Muebles   691300.0         35000.0
# 2358         Smartwatch           Electrónicos   195000.0          8600.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# ...

# %%
num_categorias = tienda['Categoría del Producto'].nunique()
print(f"Hay {num_categorias} categorías de productos diferentes en la Tienda 1.")
# Out:
# Hay 8 categorías de productos diferentes en la Tienda 1.

# %%
tienda2 = pd.read_csv(url2)

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda2.tail()
# Out:
#               Producto   Categoría del Producto     Precio  Costo de envío  \
# 2354      Set de ollas  Artículos para el hogar   140300.0          8100.0
# 2355  Lavadora de ropa        Electrodomésticos  1220100.0         65200.0
# 2356        Microondas        Electrodomésticos   797900.0         42900.0
# 2357         Iphone 15             Electrónicos  2224300.0        116600.0
# 2358         Bicicleta     Deportes y diversión   551000.0         27500.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 2354      04/12/2022  Ángel Rodriguez    Barranquilla             5
# 2355      09/02/2020   Santiago Silva          Bogotá             4
# 2356      27/09/2022   Blanca Ramirez          Bogotá             5
# 2357      21/04/2022   Juan Fernandez        Medellín             5
# 2358      03/09/2022    Maria Alfonso        Medellín             4
#
#           Método de pago  Cantidad de cuotas       lat       lon
# ...

# %%
pd.read_csv(url2, sep=";")
# Out:
#      Producto,Categoría del Producto,Precio,Costo de envío,Fecha de Compra,Vendedor,Lugar de Compra,Calificación,Método de pago,Cantidad de cuotas,lat,lon
# 0     Silla de oficina,Muebles,283600.0,15300.0,04/0...
# 1     Pandereta,Instrumentos musicales,76800.0,2300....
# 2     Cama king,Muebles,443300.0,23800.0,22/10/2021,...
# 3     Cama king,Muebles,906200.0,46400.0,04/05/2022,...
# 4     Silla de oficina,Muebles,397800.0,19400.0,26/0...
# ...                                                 ...
# 2354  Set de ollas,Artículos para el hogar,140300.0,...
# 2355  Lavadora de ropa,Electrodomésticos,1220100.0,6...
# 2356  Microondas,Electrodomésticos,797900.0,42900.0,...
# 2357  Iphone 15,Electrónicos,2224300.0,116600.0,21/0...
# 2358  Bicicleta,Deportes y diversión,551000.0,27500....
#
# [2359 rows x 1 columns]

# %%
num_categorias = tienda['Categoría del Producto'].nunique()
print(f"Hay {num_categorias} categorías de productos diferentes en la Tienda 2.")
# Out:
# Hay 8 categorías de productos diferentes en la Tienda 2.

# %%
tienda3 = pd.read_csv(url3)

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda3.tail()
# Out:
#                      Producto Categoría del Producto    Precio  \
# 2354  Dashboards con Power BI                 Libros   26700.0
# 2355  Dashboards con Power BI                 Libros   31800.0
# 2356         Silla de oficina                Muebles  477100.0
# 2357           Mesa de centro                Muebles  123100.0
# 2358      Modelado predictivo                 Libros   63400.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 2354          2100.0      21/10/2022  Ángel Rodriguez          Bogotá
# 2355          2200.0      23/06/2022   Blanca Ramirez         Pereira
# 2356         25600.0      19/02/2023    Camila Rivera       Cartagena
# 2357          4700.0      19/09/2021   Blanca Ramirez          Bogotá
# 2358          9400.0      24/05/2022  Mariana Herrera        Medellín
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 2354             5  Tarjeta de crédito                   1   4.60971 -74.08175
# ...

# %%
pd.read_csv(url3, sep=";")
# Out:
#      Producto,Categoría del Producto,Precio,Costo de envío,Fecha de Compra,Vendedor,Lugar de Compra,Calificación,Método de pago,Cantidad de cuotas,lat,lon
# 0     Secadora de ropa,Electrodomésticos,1285100.0,6...
# 1     Mesa de noche,Muebles,290100.0,13600.0,10/02/2...
# 2     Guitarra acústica,Instrumentos musicales,30350...
# 3     Balón de voleibol,Deportes y diversión,58800.0...
# 4     Armario,Muebles,521100.0,25900.0,12/01/2022,Bl...
# ...                                                 ...
# 2354  Dashboards con Power BI,Libros,26700.0,2100.0,...
# 2355  Dashboards con Power BI,Libros,31800.0,2200.0,...
# 2356  Silla de oficina,Muebles,477100.0,25600.0,19/0...
# 2357  Mesa de centro,Muebles,123100.0,4700.0,19/09/2...
# 2358  Modelado predictivo,Libros,63400.0,9400.0,24/0...
#
# [2359 rows x 1 columns]

# %%
num_categorias = tienda['Categoría del Producto'].nunique()
print(f"Hay {num_categorias} categorías de productos diferentes en la Tienda 3.")
# Out:
# Hay 8 categorías de productos diferentes en la Tienda 3.

# %%
tienda4 = pd.read_csv(url4)

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %%
tienda4.tail()
# Out:
#                 Producto   Categoría del Producto    Precio  Costo de envío  \
# 2353     Mesa de comedor                  Muebles  227700.0         12600.0
# 2354    Silla de oficina                  Muebles  342000.0         18600.0
# 2355        Vaso térmico     Deportes y diversión   36700.0          2400.0
# 2356        Set de ollas  Artículos para el hogar  151800.0          8300.0
# 2357  Cuerda para saltar     Deportes y diversión   11200.0          1300.0
#
#      Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 2353      12/02/2020   Camila Rivera        Medellín             5
# 2354      17/05/2022   Felipe Santos     Bucaramanga             5
# 2355      03/05/2022   Camila Rivera          Bogotá             5
# 2356      15/06/2020  Blanca Ramirez            Cali             5
# 2357      17/11/2021   Felipe Santos          Bogotá             5
#
#           Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
pd.read_csv(url4, sep=";")
# Out:
#      Producto,Categoría del Producto,Precio,Costo de envío,Fecha de Compra,Vendedor,Lugar de Compra,Calificación,Método de pago,Cantidad de cuotas,lat,lon
# 0     Lavavajillas,Electrodomésticos,1084800.0,56000...
# 1     Cama box,Muebles,473800.0,25400.0,03/01/2020,I...
# 2     Balón de baloncesto,Deportes y diversión,23700...
# 3     Modelado predictivo,Libros,57700.0,1300.0,23/1...
# 4     Auriculares,Electrónicos,138900.0,5600.0,25/04...
# ...                                                 ...
# 2353  Mesa de comedor,Muebles,227700.0,12600.0,12/02...
# 2354  Silla de oficina,Muebles,342000.0,18600.0,17/0...
# 2355  Vaso térmico,Deportes y diversión,36700.0,2400...
# 2356  Set de ollas,Artículos para el hogar,151800.0,...
# 2357  Cuerda para saltar,Deportes y diversión,11200....
#
# [2358 rows x 1 columns]

# %%
num_categorias = tienda['Categoría del Producto'].nunique()
print(f"Hay {num_categorias} categorías de productos diferentes en la Tienda 4.")
# Out:
# Hay 8 categorías de productos diferentes en la Tienda 4.

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# #### **Ingresos totales tienda 1**

# %%
suma_de_precios_tienda = tienda["Precio"].sum()
print(suma_de_precios_tienda)
# Out:
# 1150880400.0

# %% [markdown]
# #### **Ingresos totales tienda 2**

# %%
suma_de_precios_tienda2 = tienda2["Precio"].sum()
print(suma_de_precios_tienda2)
# Out:
# 1116343500.0

# %% [markdown]
# #### **Ingresos totales tienda 3**

# %%
suma_de_precios_tienda3 = tienda3["Precio"].sum()
print(suma_de_precios_tienda3)
# Out:
# 1098019600.0

# %% [markdown]
# #### **Ingresos totales tienda 4**

# %%
suma_de_precios_tienda4 = tienda4["Precio"].sum()
print(suma_de_precios_tienda4)
# Out:
# 1038375700.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(ingresos_totales['Tienda'], ingresos_totales['Ingresos Totales'])
plt.title('Ingresos Totales por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingresos Totales')
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# #### **Cantidad de productos vendidos por categoria tienda 1**

# %%
nombres_categorias_tienda1 = tienda['Categoría del Producto'].unique()
print("Nombres de las categorías de productos en la Tienda 1:")
display(nombres_categorias_tienda1)
# Out:
# Nombres de las categorías de productos en la Tienda 1:
# array(['Electrónicos', 'Muebles', 'Juguetes', 'Electrodomésticos',
#        'Artículos para el hogar', 'Deportes y diversión', 'Libros',
#        'Instrumentos musicales'], dtype=object)

# %%
ventas_por_categoria_tienda = tienda.groupby('Categoría del Producto').size().reset_index(name='Cantidad Vendida')

# %%
categoria_mas_vendida_tienda = ventas_por_categoria_tienda.loc[ventas_por_categoria_tienda['Cantidad Vendida'].idxmax()]

# %%
print("Ventas por categoría en la Tienda :")
display(ventas_por_categoria_tienda.sort_values(by="Cantidad Vendida", ascending=False))
print("\nCategoría más vendida en la Tienda :")
display(categoria_mas_vendida_tienda)
# Out:
# Ventas por categoría en la Tienda :
#     Categoría del Producto  Cantidad Vendida
# 7                  Muebles               465
# 3             Electrónicos               448
# 5                 Juguetes               324
# 2        Electrodomésticos               312
# 1     Deportes y diversión               284
# 4   Instrumentos musicales               182
# 6                   Libros               173
# 0  Artículos para el hogar               171
# Categoría más vendida en la Tienda :
# Categoría del Producto    Muebles
# Cantidad Vendida              465
# Name: 7, dtype: object

# %% [markdown]
# #### **Cantidad de productos vendidos por categoria tienda 2**

# %%
nombres_categorias_tienda2 = tienda2['Categoría del Producto'].unique()
print("Nombres de las categorías de productos en la Tienda 2:")
display(nombres_categorias_tienda2)
# Out:
# Nombres de las categorías de productos en la Tienda 2:
# array(['Muebles', 'Instrumentos musicales', 'Deportes y diversión',
#        'Electrónicos', 'Artículos para el hogar', 'Juguetes',
#        'Electrodomésticos', 'Libros'], dtype=object)

# %%
ventas_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto').size().reset_index(name='Cantidad Vendida')

# %%
categoria_mas_vendida_tienda2 = ventas_por_categoria_tienda2.loc[ventas_por_categoria_tienda2['Cantidad Vendida'].idxmax()]

# %%
print("Ventas por categoría en la Tienda 2:")
display(ventas_por_categoria_tienda2.sort_values(by="Cantidad Vendida", ascending=False))
print("\nCategoría más vendida en la Tienda 2:")
display(categoria_mas_vendida_tienda2)
# Out:
# Ventas por categoría en la Tienda 2:
#     Categoría del Producto  Cantidad Vendida
# 7                  Muebles               442
# 3             Electrónicos               422
# 5                 Juguetes               313
# 2        Electrodomésticos               305
# 1     Deportes y diversión               275
# 4   Instrumentos musicales               224
# 6                   Libros               197
# 0  Artículos para el hogar               181
# Categoría más vendida en la Tienda 2:
# Categoría del Producto    Muebles
# Cantidad Vendida              442
# Name: 7, dtype: object

# %% [markdown]
# #### **Cantidad de productos vendidos por categoria tienda 3**

# %%
nombres_categorias_tienda3 = tienda3['Categoría del Producto'].unique()
print("Nombres de las categorías de productos en la Tienda 3:")
display(nombres_categorias_tienda3)
# Out:
# Nombres de las categorías de productos en la Tienda 3:
# array(['Electrodomésticos', 'Muebles', 'Instrumentos musicales',
#        'Deportes y diversión', 'Electrónicos', 'Juguetes',
#        'Artículos para el hogar', 'Libros'], dtype=object)

# %%
ventas_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto').size().reset_index(name='Cantidad Vendida')

# %%
categoria_mas_vendida_tienda3 = ventas_por_categoria_tienda3.loc[ventas_por_categoria_tienda3['Cantidad Vendida'].idxmax()]

# %%
print("Ventas por categoría en la Tienda 3:")
display(ventas_por_categoria_tienda3.sort_values(by="Cantidad Vendida", ascending=False))
print("\nCategoría más vendida en la Tienda 3:")
display(categoria_mas_vendida_tienda3)
# Out:
# Ventas por categoría en la Tienda 3:
#     Categoría del Producto  Cantidad Vendida
# 7                  Muebles               499
# 3             Electrónicos               451
# 5                 Juguetes               315
# 2        Electrodomésticos               278
# 1     Deportes y diversión               277
# 6                   Libros               185
# 0  Artículos para el hogar               177
# 4   Instrumentos musicales               177
# Categoría más vendida en la Tienda 3:
# Categoría del Producto    Muebles
# Cantidad Vendida              499
# Name: 7, dtype: object

# %% [markdown]
# #### **Cantidad de productos vendidos por categoria tienda 4**

# %%
nombres_categorias_tienda4 = tienda4['Categoría del Producto'].unique()
print("Nombres de las categorías de productos en la Tienda 4:")
display(nombres_categorias_tienda4)
# Out:
# Nombres de las categorías de productos en la Tienda 4:
# array(['Electrodomésticos', 'Muebles', 'Deportes y diversión', 'Libros',
#        'Electrónicos', 'Instrumentos musicales', 'Juguetes',
#        'Artículos para el hogar'], dtype=object)

# %%
ventas_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto').size().reset_index(name='Cantidad Vendida')

# %%
categoria_mas_vendida_tienda4 = ventas_por_categoria_tienda4.loc[ventas_por_categoria_tienda4['Cantidad Vendida'].idxmax()]

# %%
print("Ventas por categoría en la Tienda 4:")
display(ventas_por_categoria_tienda4.sort_values(by="Cantidad Vendida", ascending=False))
print("\nCategoría más vendida en la Tienda 4:")
display(categoria_mas_vendida_tienda4)
# Out:
# Ventas por categoría en la Tienda 4:
#     Categoría del Producto  Cantidad Vendida
# 7                  Muebles               480
# 3             Electrónicos               451
# 5                 Juguetes               338
# 1     Deportes y diversión               277
# 2        Electrodomésticos               254
# 0  Artículos para el hogar               201
# 6                   Libros               187
# 4   Instrumentos musicales               170
# Categoría más vendida en la Tienda 4:
# Categoría del Producto    Muebles
# Cantidad Vendida              480
# Name: 7, dtype: object

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='Categoría del Producto', y='Cantidad Vendida', hue='Tienda', data=ventas_por_categoria_combinada_melt)
plt.title('Cantidad de Productos Vendidos por Categoría por Tienda')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad Vendida')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# #### Calificacion Tienda 1

# %%
calificacion_promedio_tienda1 = tienda['Calificación'].mean()

# %%
print(f"La calificación promedio de la Tienda 1 es: {calificacion_promedio_tienda1:.2f}")
# Out:
# La calificación promedio de la Tienda 1 es: 3.98

# %% [markdown]
# #### Calificacion Tienda 2

# %%
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()

# %%
print(f"La calificación promedio de la Tienda 2 es: {calificacion_promedio_tienda2:.2f}")
# Out:
# La calificación promedio de la Tienda 2 es: 4.04

# %% [markdown]
# #### Calificacion Tienda 3

# %%
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()

# %%
print(f"La calificación promedio de la Tienda 3 es: {calificacion_promedio_tienda3:.2f}")
# Out:
# La calificación promedio de la Tienda 3 es: 4.05

# %% [markdown]
# #### Calificacion Tienda 4

# %%
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

# %%
print(f"La calificación promedio de la Tienda 4 es: {calificacion_promedio_tienda4:.2f}")
# Out:
# La calificación promedio de la Tienda 4 es: 4.00

# %%
plt.figure(figsize=(10, 6))
sns.pointplot(x='Tienda', y='Calificación Promedio', data=calificaciones_promedio)
plt.title('Calificación Promedio por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# #### Productos mas y menos vendido Tienda 1

# %%
conteo_productos_tienda1 = tienda['Producto'].value_counts()

# %%
producto_mas_vendido_tienda1 = conteo_productos_tienda1.head(5)
producto_menos_vendido_tienda1 = conteo_productos_tienda1.tail(5)

# %%
print("Productos más vendidos en la Tienda 1:")
display(producto_mas_vendido_tienda1)

print("\nProductos menos vendidos en la Tienda 1:")
display(producto_menos_vendido_tienda1)
# Out:
# Productos más vendidos en la Tienda 1:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# Productos menos vendidos en la Tienda 1:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %% [markdown]
# #### Productos mas y menos vendido Tienda 2

# %%
conteo_productos_tienda2 = tienda2['Producto'].value_counts()

# %%
producto_mas_vendido_tienda2 = conteo_productos_tienda2.head(5)
producto_menos_vendido_tienda2 = conteo_productos_tienda2.tail(5)

# %%
print("Productos más vendidos en la Tienda 2:")
display(producto_mas_vendido_tienda2)

print("\nProductos menos vendidos en la Tienda 2:")
display(producto_menos_vendido_tienda2)
# Out:
# Productos más vendidos en la Tienda 2:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# Productos menos vendidos en la Tienda 2:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64

# %% [markdown]
# #### Productos mas y menos vendido Tienda 3

# %%
conteo_productos_tienda3 = tienda3['Producto'].value_counts()

# %%
producto_mas_vendido_tienda3 = conteo_productos_tienda3.head(5)
producto_menos_vendido_tienda3 = conteo_productos_tienda3.tail(5)

# %%
print("Productos más vendidos en la Tienda 3:")
display(producto_mas_vendido_tienda3)

print("\nProductos menos vendidos en la Tienda 3:")
display(producto_menos_vendido_tienda3)
# Out:
# Productos más vendidos en la Tienda 3:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64
# Productos menos vendidos en la Tienda 3:
# Producto
# Guitarra eléctrica         38
# Set de vasos               36
# Mochila                    36
# Microondas                 36
# Bloques de construcción    35
# Name: count, dtype: int64

# %% [markdown]
# #### Prodcutos mas y menos vendidos tienda 4

# %%
conteo_productos_tienda4 = tienda4['Producto'].value_counts()

# %%
producto_mas_vendido_tienda4 = conteo_productos_tienda4.head(5)
producto_menos_vendido_tienda4 = conteo_productos_tienda4.tail(5)

# %%
print("Productos más vendidos en la Tienda 4:")
display(producto_mas_vendido_tienda4)

print("\nProductos menos vendidos en la Tienda 4:")
display(producto_menos_vendido_tienda4)
# Out:
# Productos más vendidos en la Tienda 4:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64
# Productos menos vendidos en la Tienda 4:
# Producto
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio_promedio_tienda1 = tienda['Costo de envío'].mean()

print(f"El costo de envío promedio de la Tienda 1 es: {costo_envio_promedio_tienda1:.2f}")
# Out:
# El costo de envío promedio de la Tienda 1 es: 26018.61

# %%
costo_envio_promedio_tienda2 = tienda2['Costo de envío'].mean()

print(f"El costo de envío promedio de la Tienda 2 es: {costo_envio_promedio_tienda2:.2f}")
# Out:
# El costo de envío promedio de la Tienda 2 es: 25216.24

# %%
costo_envio_promedio_tienda3 = tienda3['Costo de envío'].mean()

print(f"El costo de envío promedio de la Tienda 3 es: {costo_envio_promedio_tienda3:.2f}")
# Out:
# El costo de envío promedio de la Tienda 3 es: 24805.68

# %%
costo_envio_promedio_tienda4 = tienda4['Costo de envío'].mean()

print(f"El costo de envío promedio de la Tienda 4 es: {costo_envio_promedio_tienda4:.2f}")
# Out:
# El costo de envío promedio de la Tienda 4 es: 23459.46

# %% [markdown]
# ## Introducción al Informe Final
#
# ### Propósito del Análisis
#
# Estimado Sr. Juan,
#
# El presente informe tiene como propósito principal realizar un análisis exhaustivo de la eficiencia operativa y comercial de sus cuatro tiendas: Tienda 1, Tienda 2, Tienda 3 y Tienda 4. Este estudio se basa en una evaluación detallada de métricas clave que incluyen los ingresos totales generados, el rendimiento de las ventas por categoría de productos, la satisfacción del cliente reflejada en las calificaciones promedio, la identificación de los productos más y menos vendidos, y el análisis de los costos de envío promedio. Nuestro objetivo fundamental con este análisis es identificar la tienda que presenta la menor eficiencia operativa y estratégica, con el fin de proporcionar una recomendación fundamentada sobre su posible venta.

# %% [markdown]
# ### Resumen Consolidado de Hallazgos por Tienda
#
# Para facilitar la toma de decisiones, presentamos un resumen consolidado de los hallazgos clave para cada una de sus tiendas, abarcando los análisis de ingresos, ventas por categoría, calificaciones de clientes, productos más y menos vendidos, y costos de envío.
#
# #### Tienda 1
# *   **Ingresos Totales:** La Tienda 1 es la que genera los ingresos totales más altos (aproximadamente 1,151 millones de pesos), lo que la posiciona como la líder económica.
# *   **Ventas por Categoría:** 'Muebles' y 'Electrónicos' son las categorías más vendidas. Sin embargo, 'Artículos para el hogar', 'Libros' e 'Instrumentos musicales' son las categorías menos vendidas. Tiene la menor cantidad de ventas en 'Artículos para el hogar' (171 unidades).
# *   **Calificación Promedio:** La más baja entre todas las tiendas (3.98), lo que sugiere un área de oportunidad en la satisfacción del cliente a pesar de sus altos ingresos.
# *   **Productos (Top 5 / Bottom 5):** 'Microondas', 'TV LED UHD 4K', y 'Armario' están entre los más vendidos. 'Ciencia de datos con Python', 'Pandereta' y 'Celular ABXY' son de los menos vendidos.
# *   **Costo de Envío Promedio:** El más alto (aproximadamente 26,019 pesos), lo que podría impactar su rentabilidad neta si no se gestiona eficientemente.
#
# #### Tienda 2
# *   **Ingresos Totales:** Ocupa el segundo lugar en ingresos totales (aproximadamente 1,116 millones de pesos), mostrando un desempeño financiero robusto.
# *   **Ventas por Categoría:** Similar a la Tienda 1, 'Muebles' y 'Electrónicos' lideran. 'Artículos para el hogar', 'Libros' e 'Instrumentos musicales' son las categorías menos vendidas.
# *   **Calificación Promedio:** Muy alta (4.04), indicando un buen nivel de satisfacción del cliente.
# *   **Productos (Top 5 / Bottom 5):** 'Iniciando en programación', 'Microondas' y 'Batería' son muy populares. 'Auriculares', 'Sillón' y 'Juego de mesa' son de los menos vendidos.
# *   **Costo de Envío Promedio:** Segundo más alto (aproximadamente 25,216 pesos).
#
# #### Tienda 3
# *   **Ingresos Totales:** Se ubica en tercer lugar (aproximadamente 1,098 millones de pesos).
# *   **Ventas por Categoría:** Lidera en ventas de 'Muebles' (499 unidades) y comparte el liderazgo en 'Electrónicos'. 'Artículos para el hogar', 'Instrumentos musicales' y 'Libros' son las categorías menos vendidas.
# *   **Calificación Promedio:** La más alta de todas (4.05), reflejando una excelente satisfacción del cliente.
# *   **Productos (Top 5 / Bottom 5):** 'Kit de bancas', 'Mesa de comedor' y 'Cama king' son top ventas. 'Guitarra eléctrica', 'Set de vasos' y 'Bloques de construcción' son de los menos vendidos.
# *   **Costo de Envío Promedio:** Tercero más alto (aproximadamente 24,806 pesos).
#
# #### Tienda 4
# *   **Ingresos Totales:** La más baja en ingresos totales (aproximadamente 1,038 millones de pesos), con una diferencia notable respecto a las otras.
# *   **Ventas por Categoría:** 'Muebles' y 'Electrónicos' siguen siendo las más vendidas, y lidera en 'Juguetes' (338 unidades). Registra la menor cantidad de ventas en 'Instrumentos musicales' (170 unidades). 'Libros' y 'Artículos para el hogar' también tienen bajo rendimiento.
# *   **Calificación Promedio:** Buena (4.00), lo que es positivo a pesar de los bajos ingresos.
# *   **Productos (Top 5 / Bottom 5):** 'Cama box', 'Cubertería' y 'Dashboards con Power BI' están entre los más vendidos. Sin embargo, 'Refrigerador', 'Armario' y 'Guitarra eléctrica' son de los menos vendidos, incluyendo productos que son populares en otras tiendas.
# *   **Costo de Envío Promedio:** El más bajo (aproximadamente 23,459 pesos), lo que indica una mayor eficiencia en logística de envío.

# %% [markdown]
# ### Comparación de Fortalezas y Debilidades por Tienda
#
# Al comparar las cuatro tiendas a través de las métricas clave, emergen patrones claros de fortalezas y debilidades:
#
# **1. Ingresos Totales:**
# *   **Fortaleza:** La **Tienda 1** es claramente la líder en ingresos, seguida de cerca por la **Tienda 2** y **Tienda 3**.
# *   **Debilidad:** La **Tienda 4** registra los ingresos más bajos, con una diferencia sustancial respecto a las demás.
#
# **2. Ventas por Categoría:**
# *   **Fortaleza Común:** 'Muebles' y 'Electrónicos' son consistentemente las categorías más vendidas en todas las tiendas.
# *   **Debilidad Común:** 'Artículos para el hogar', 'Libros' e 'Instrumentos musicales' son las menos vendidas en general.
# *   **Tienda 3** muestra el mayor volumen de ventas en 'Muebles'.
# *   **Tienda 4** lidera en 'Juguetes' pero tiene el menor volumen en 'Instrumentos musicales'.
#
# **3. Calificación Promedio:**
# *   **Fortaleza:** La **Tienda 3** tiene la calificación promedio más alta (4.05), seguida muy de cerca por la **Tienda 2** (4.04) y la **Tienda 4** (4.00), lo que indica una buena satisfacción general del cliente en estas tiendas.
# *   **Debilidad:** La **Tienda 1**, a pesar de sus altos ingresos, tiene la calificación promedio más baja (3.98). Aunque no es mala, sugiere oportunidades de mejora en la experiencia del cliente.
#
# **4. Productos Más y Menos Vendidos:**
# *   **Diversidad y Especialización:** La popularidad de productos varía, aunque hay una tendencia general de que algunos muebles y electrodomésticos son fuertes.
# *   La **Tienda 2** destaca por la venta de libros de programación y algunos instrumentos musicales, mostrando una posible especialización de nicho.
# *   La **Tienda 4** tiene productos populares como 'Cama box' y 'Dashboards con Power BI', pero falla en vender consistentemente productos como 'Refrigerador' y 'Armario', que son pilares en otras tiendas.
#
# **5. Costo de Envío Promedio:**
# *   **Fortaleza:** La **Tienda 4** tiene el costo de envío promedio más bajo (23,459 pesos), lo que indica una mayor eficiencia logística.
# *   **Debilidad:** La **Tienda 1** tiene el costo de envío promedio más alto (26,019 pesos), lo que podría erosionar sus márgenes de ganancia a pesar de sus altos ingresos.
#
# ### Identificación de la Tienda Menos Eficiente
#
# Considerando todas las métricas, la **Tienda 4** se perfila como la candidata más clara para ser considerada la menos eficiente y, por ende, la más adecuada para la venta.
#
# Aunque la Tienda 4 muestra algunas fortalezas (buena calificación promedio y el costo de envío más bajo, lo que implica una eficiencia operativa en la entrega), sus **ingresos totales son significativamente los más bajos**. Esta métrica es fundamental para la sostenibilidad y el éxito financiero de una empresa.
#
# Además, la Tienda 4 presenta inconsistencias importantes en la venta de productos que son populares en otras tiendas (ej., 'Refrigerador' y 'Armario' son productos menos vendidos), lo que sugiere una menor capacidad para capitalizar la demanda general del mercado o problemas de posicionamiento de su catálogo.
#
# Si bien la Tienda 1 tiene la calificación más baja y el costo de envío más alto, su liderazgo abrumador en ingresos totales la hace una pieza fundamental del negocio que, con ajustes, podría mejorar su rentabilidad y satisfacción.
#
# La Tienda 2 y Tienda 3, con ingresos robustos y altas calificaciones, demuestran un excelente desempeño general.
#
# ### Recomendación Final
#
# **Se recomienda al Sr. Juan vender la Tienda 4.**
#
# La justificación para esta decisión radica en que la **Tienda 4 es consistentemente la que menor volumen de negocio aporta a la empresa, registrando los ingresos totales más bajos.** A pesar de tener un buen desempeño en satisfacción del cliente y eficiencia en costos de envío, estos aspectos positivos no logran compensar la significativa brecha en facturación con respecto a las otras tiendas.
#
# Mantener una tienda con ingresos consistentemente bajos puede diluir la rentabilidad general de la empresa, desviar recursos que podrían ser mejor invertidos en las tiendas más exitosas (Tienda 1, 2 y 3), o generar mayores retornos. Los recursos liberados de la venta de la Tienda 4 podrían ser reasignados para mejorar la eficiencia y la satisfacción del cliente en la Tienda 1, o para expandir las operaciones de las Tiendas 2 y 3, que muestran un equilibrio más sólido entre ingresos y satisfacción.
